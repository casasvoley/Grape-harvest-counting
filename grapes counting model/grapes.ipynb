# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from ultralytics import YOLO
import torch
torch.cuda.is_available()
# Out:
# 0

# %%
# Load a model
model = YOLO("pretrained_yolov8n.pt")  # load a pretrained model

# %%
# Train the model
results = model.train(data="/content/Grape-harvest-counting/grapes counting model/grapes_params.yaml", imgsz=800, augment=True, dropout=0.3, patience=25, momentum=0.9, weight_decay=0.0001, lr0=0.0001, lrf=0.00001, batch=16, epochs=100, plots=True, device='tpu', val=True, optimizer='Adam')
# Out:
# Ultralytics YOLOv8.0.105 🚀 Python-3.10.11 torch-2.0.1+cu118
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f64bc2e1453b> in <cell line: 2>()
#       1 # Train the model
# ----> 2 results = model.train(data="/content/gdrive/MyDrive/Colab Notebooks/yolov8_grapes-main/grapes.yaml", imgsz=800, augment=True, dropout=0.3, patience=25, momentum=0.9, weight_decay=0.0001, lr0=0.0001, lrf=0.00001, batch=16, epochs=100, plots=True, device='tpu', val=True, optimizer='Adam')
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     364             overrides['resume'] = self.ckpt_path
#     365         self.task = overrides.get('task') or self.task
# --> 366         self.trainer = TASK_MAP[self.task][1](overrides=overrides, _callbacks=self.callbacks)
# ...

# %%
model = YOLO("/Users/baudi/AI/practicas/grapes/runs/detect/train58/weights/best.pt")
model.val(data="/Users/baudi/AI/practicas/grapes/grapes.yaml")

# %%
model = YOLO("/Users/baudi/AI/practicas/grapes/runs/detect/train90/weights/best.pt")
results = model.predict(source="/Users/baudi/AI/practicas/grapes/datasets/test", save=True, save_txt=True, agnostic_nms=False, iou=0.25, line_width=5, conf=0.16, show_labels=False)
